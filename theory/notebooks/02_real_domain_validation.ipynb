# %% [markdown]
# # Theory Notebook 2 — Real Domain Validation
#
# Tests theoretical α*(β) against empirical optima from the master's ablation study across all 5 domains.
#
# **Input:** `data/results/ablation_exploration_prior.csv` (from bvr/experiments/ablations.py)
#
# **Output:** Theory-empirics comparison table → Figure 2 of Paper P1.

# %%
import sys, pandas as pd
sys.path.insert(0, '../../')
from theory.code.theoretical_alpha import predict_and_compare

# Load existing ablation results
abl = pd.read_csv('../../data/results/ablation_exploration_prior.csv')
print(abl.head())

# TODO: for each dataset, load train data, call predict_and_compare
# Expected: theoretical α* ≈ empirical best α within ±0.25
print('\nReady to validate theory against ablation data')
