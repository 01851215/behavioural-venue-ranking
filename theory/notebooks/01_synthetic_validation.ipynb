# %% [markdown]
# # Theory Notebook 1 — Synthetic Validation of Prior-Domain Match Theorem
#
# Verifies that the theoretical α*(β) prediction matches the empirically optimal α on synthetic bipartite graphs with controlled behavioral modes.
#
# **Thesis contribution:** This notebook produces Figure 1 of Paper P1 (theory paper).

# %%
import sys, numpy as np, pandas as pd
sys.path.insert(0, '../../')
from theory.code.theoretical_alpha import estimate_behavioral_mode, theoretical_optimal_alpha

# TODO: generate synthetic bipartite graphs with varying β
# Run α sweep on each, find empirical best α
# Compare to theoretical prediction
print('Notebook ready — implement synthetic graph generation in Phase 1, Year 1')
